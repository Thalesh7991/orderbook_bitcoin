# %% [markdown]
# # 0.0 Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %% [markdown]
# ## 1.0 Gráficos

# %% [markdown]
# - Utilizando dados sintéticos

# %%
# Função para gerar dados sintéticos
def generate_synthetic_data(num_points=100):
    prices = np.linspace(10000, 12000, num_points)
    buy_orders = [random.randint(1, 10) for _ in range(num_points)]
    sell_orders = [random.randint(1, 10) for _ in range(num_points)]
    return prices, buy_orders, sell_orders

# Função para atualizar os dados e plotar as visualizações
def update_and_plot(ax1, ax2, ax3):
    prices, buy_orders, sell_orders = generate_synthetic_data()

    ax1.clear()
    ax1.fill_between(prices, buy_orders, color='b', alpha=0.7, label='Compra')
    ax1.set_title('Ordens de Compra')
    ax1.set_xlabel('Preço do Bitcoin')
    ax1.set_ylabel('Quantidade de Ordens de Compra')
    ax1.legend()

    ax2.clear()
    ax2.fill_between(prices, sell_orders, color='r', alpha=0.7, label='Venda')
    ax2.set_title('Ordens de Venda')
    ax2.set_xlabel('Preço do Bitcoin')
    ax2.set_ylabel('Quantidade de Ordens de Venda')
    ax2.legend()

    ax3.clear()
    price_variation = [0.1, 0.5, 1.0, 5.0, 10.0]
    btc_to_trade = [random.uniform(100, 500) for _ in range(len(price_variation))]
    ax3.bar(price_variation, btc_to_trade, color='g', alpha=0.7)
    ax3.set_title('Quantidade de Bitcoin para Variar o Preço')
    ax3.set_xlabel('Variação Percentual do Preço')
    ax3.set_ylabel('Quantidade de Bitcoin')

    plt.pause(1)  
    plt.show()

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 6))  

for _ in range(10):
    update_and_plot(ax1, ax2, ax3)

plt.show()

# %%
import requests

url = "https://brasilbitcoin.com.br/API/orderbook/BTC"

response = requests.get(url)

data = response.json()

print(data)
# Out:
# {'buy': [{'id': 435642430, 'preco': 211143.26, 'quantidade': 0.07093, 'valor': 14976.39}, {'id': 435642429, 'preco': 211140.29, 'quantidade': 0.10555299, 'valor': 22286.49}, {'id': 435642419, 'preco': 211140.28, 'quantidade': 0.07286, 'valor': 15383.68}, {'id': 435642105, 'preco': 210001, 'quantidade': 0.04665, 'valor': 9796.55}, {'id': 435642320, 'preco': 210000.01, 'quantidade': 0.21506958, 'valor': 45164.61}, {'id': 435474040, 'preco': 210000, 'quantidade': 1.72e-05, 'valor': 3.61}, {'id': 435489438, 'preco': 209999.99, 'quantidade': 5.714e-05, 'valor': 12}, {'id': 435641577, 'preco': 209970.6, 'quantidade': 4.763e-05, 'valor': 10}, {'id': 435454693, 'preco': 209780, 'quantidade': 0.00193559, 'valor': 406.05}, {'id': 435641588, 'preco': 209650.63, 'quantidade': 0.38572794, 'valor': 80868.11}, {'id': 435438682, 'preco': 209650.5, 'quantidade': 0.17395088, 'valor': 36468.89}, {'id': 435481651, 'preco': 209358.64, 'quantidade': 0.0009553, 'valor': 200}, {'id': 435642316, 'preco': 209032.5, 'quantidade': 1.05910565, 'valor': 221387.5}, {'id': 435569403, 'preco': 208697, 'quantidade': 0.04791157, 'valor': 9999}, {'id': 435147991, 'preco': 208500, 'quantidade': 0.00479616, 'valor': 1000}, {'id': 435146074, 'preco': 208000, 'quantidade': 0.00480769, 'valor': 1000}, {'id': 435150793, 'preco': 208000, 'quantidade': 0.0002885, 'valor': 60.01}, {'id': 435155370, 'preco': 207900, 'quantidade': 0.00481, 'valor': 1000}, {'id': 435485700, 'preco': 207520, 'quantidade': 0.01298785, 'valor': 2695.24}, {'id': 435149218, 'preco': 207322.54, 'quantidade': 0.00096468, 'valor': 200}, {'id': 435188343, 'preco': 207200